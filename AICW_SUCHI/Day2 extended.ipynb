# %% [markdown]
# ###oops

# %%
class student:
    pass

# %% [markdown]
# i=student()

# %%
i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 i
#
# NameError: name 'i' is not defined

# %%
class student:
    def __init__(self , name,place):
        self.name=name
        self.place=place
    def show(self):
        return f'The name is {self.name} and you are from {self.place}'

# %%
p1= student('ABC','Mysuru')

# %%
p1.show()
# Out:
# 'The name is ABC and you are from Mysuru'

# %%
class Student:
    def __init__(std,usn,name,place):
        std.usn=usn
        std.name=name
        std.place=place
    def show(std):#instance method
        print(f'USN of {std.usn} having the name {std.name},is from{std.place}')
    def update(std,usn,place):
        std.usn=usn
        std.place=place

# %%
stud = Student(130 ,'RMS','Mysuru')
stud.name
# Out:
# 'RMS'

# %%
stud.show()
# Out:
# USN of 130 having the name RMS,is fromMysuru

# %%
stud.update(19,'bnglr')

# %%
stud.show()
# Out:
# USN of 19 having the name RMS,is frombnglr
